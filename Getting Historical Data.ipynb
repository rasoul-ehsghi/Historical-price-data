# %%
! pip install yfinance

# %%
import yfinance as yf

#Define ticker symbol

ticker_symbol = "AAPL"

# Create a ticker object

ticker = yf.Ticker(ticker_symbol)

# Download Historical Data
historical_data = ticker.history(start = "1990-01-01", end="2022-12-21", interval='1d')
historical_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1990-01-02 00:00:00-05:00    0.249271    0.265181    0.247503    0.263414
# 1990-01-03 00:00:00-05:00    0.268718    0.268718    0.265181    0.265181
# 1990-01-04 00:00:00-05:00    0.270486    0.274021    0.263414    0.266066
# 1990-01-05 00:00:00-05:00    0.266950    0.270486    0.261646    0.266950
# 1990-01-08 00:00:00-05:00    0.265181    0.268718    0.261646    0.268718
# ...                               ...         ...         ...         ...
# 2022-12-14 00:00:00-05:00  144.542091  145.844807  140.375378  142.413986
# 2022-12-15 00:00:00-05:00  140.325632  141.011799  135.273868  135.741257
# 2022-12-16 00:00:00-05:00  135.930220  136.884875  132.986666  133.762329
# 2022-12-19 00:00:00-05:00  134.358991  134.448488  130.590065  131.634216
# 2022-12-20 00:00:00-05:00  130.659676  132.509337  129.168013  131.564621
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
# inCase if you want to download the last days or shorter period use the following method:

history_data = ticker.history(period = "20d", interval = "1d")
history_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-12-01 00:00:00-05:00  190.330002  191.559998  189.229996  191.240005
# 2023-12-04 00:00:00-05:00  189.979996  190.050003  187.449997  189.429993
# 2023-12-05 00:00:00-05:00  190.210007  194.399994  190.179993  193.419998
# 2023-12-06 00:00:00-05:00  194.449997  194.759995  192.110001  192.320007
# 2023-12-07 00:00:00-05:00  193.630005  195.000000  193.589996  194.270004
# 2023-12-08 00:00:00-05:00  194.199997  195.990005  193.669998  195.710007
# 2023-12-11 00:00:00-05:00  193.110001  193.490005  191.419998  193.179993
# 2023-12-12 00:00:00-05:00  193.080002  194.720001  191.720001  194.710007
# 2023-12-13 00:00:00-05:00  195.089996  198.000000  194.850006  197.960007
# 2023-12-14 00:00:00-05:00  198.020004  199.619995  196.160004  198.110001
# 2023-12-15 00:00:00-05:00  197.529999  198.399994  197.000000  197.570007
# 2023-12-18 00:00:00-05:00  196.089996  196.630005  194.389999  195.889999
# ...
